# %% [markdown]
# Answers for Week 1
#
# * Name: Dhanish Shah
# * Username: dshah
# * Student s-number: S6221785
# * Group (AS1, etc.): AS5

# %% [markdown]
# x=22/7

# %% [markdown]
# $$y=\frac{sin(x)}{x}$$

# %%
pi = 22/7 # Processed on Jupyter Hub

# %%
## Question 1.5 ##

from scipy.constants import G
Me = 5.9722e24
Mm = 7.342e22
r = 385000.6 
F = (G*Me*Mm/r**2)
print ("The force of attraction is:",F)
# Out:
# The force of attraction is: 1.9743840518075717e+26
