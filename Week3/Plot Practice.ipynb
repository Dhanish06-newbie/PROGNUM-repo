# %%
import numpy as np
import matplotlib.pyplot as plt
d = np.array([18.49, 35.48, 35.48, 11.34, 7.12, 9.82, 23.66, 44, 66.7, 52.4, 55, 25.6, 26.19])
v = np.array([2094.75, 2320.87, 1224.9, 872.13, 432.2, 751, 1410, 2700, 5292, 2550, 5253, 2419, 2158])
slope, intercept = np.polyfit(d,v,1)
print (f"Slope is : , {slope} and intercept is : {intercept}")

#Plotting
plt.scatter (d,v,marker ='^', label = 'Observed Data')
plt.legend()
plt.grid()

plt.title("Ooga Booga")
plt.xlabel(' $d$ (Mpc)')
plt.ylabel(' $v$ (km/s)')
plt.xticks(fontsize=16)
plt.yticks(fontsize=12)

plt.plot(d_line, H0_planck * d_line, '--', label=r'Planck 2018 ($H_0 = 67.66$)')
plt.plot(d_line, slope * d_line + intercept, '-', label=f'Best Fit ($H_0 \\approx {slope:.2f}$)')
# Out:
# Slope is : , 71.38295626595355 and intercept is : 9.189826687586365
# (array([   0., 1000., 2000., 3000., 4000., 5000., 6000.]),
#  [Text(0, 0.0, '0'),
#   Text(0, 1000.0, '1000'),
#   Text(0, 2000.0, '2000'),
#   Text(0, 3000.0, '3000'),
#   Text(0, 4000.0, '4000'),
#   Text(0, 5000.0, '5000'),
#   Text(0, 6000.0, '6000')])

# %%
plt.scatter(d, v, marker='D', color='green', label=r'Observed Data')

plt.legend()
plt.grid()
plt.title(r'Hubble Law: Velocity $v$ vs Distance $d$')

plt.xlabel(r'Distance $d$ (Mpc)')
plt.ylabel(r'Velocity $v$ (km/s)')
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

plt.plot(d_line, H0_planck * d_line, '--', label=r'Planck 2018 ($H_0 = 67.66$)')
plt.plot(d_line, slope * d_line + intercept, '-', label=f'Best Fit ($H_0 \\approx {slope:.2f}$)')
plt.savefig('hubble_plot.png')
